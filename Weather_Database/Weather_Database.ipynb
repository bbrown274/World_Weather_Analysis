# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = list(zip(lats, lngs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | birnin kebbi
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | lepe
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | kambove
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | puerto berrio
# Processing Record 17 of Set 1 | lesnoy
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | sola
# Processing Record 23 of Set 1 | acurenam
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | youkounkoun
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | moron
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | alofi
# Processing Record 31 of Set 1 | hovd
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | korla
# Processing Record 36 of Set 1 | bucerias
# Processing Record 37 of Set 1 | isangel
# Processing Record 38 of Set 1 | prince rupert
# Processing Record 39 of Set 1 | sao joao da barra
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | jiazi
# Processing Record 42 of Set 1 | ngunguru
# Processing Record 43 of Set 1 | oum hadjer
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | ushtobe
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | marienburg
# Processing Record 49 of Set 1 | cap malheureux
# Processing Record 50 of Set 1 | peniche
# Processing Record 1 of Set 2 | leh
# Processing Record 2 of Set 2 | inhambane
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | songjianghe
# Processing Record 6 of Set 2 | laguna
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | tigzirt
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | pontes e lacerda
# Processing Record 12 of Set 2 | hay river
# Processing Record 13 of Set 2 | kalmunai
# Processing Record 14 of Set 2 | krasnoselkup
# Processing Record 15 of Set 2 | aloja
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | tashtagol
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | tezu
# Processing Record 20 of Set 2 | ulladulla
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | slave lake
# Processing Record 25 of Set 2 | parangan
# Processing Record 26 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | portland
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | lavrentiya
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | rongu
# City not found. Skipping...
# Processing Record 33 of Set 2 | liku
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | kralendijk
# Processing Record 39 of Set 2 | shahrud
# Processing Record 40 of Set 2 | itea
# Processing Record 41 of Set 2 | wazzan
# City not found. Skipping...
# Processing Record 42 of Set 2 | leningradskiy
# Processing Record 43 of Set 2 | sambava
# Processing Record 44 of Set 2 | albacete
# Processing Record 45 of Set 2 | nago
# Processing Record 46 of Set 2 | seoni malwa
# Processing Record 47 of Set 2 | opuwo
# Processing Record 48 of Set 2 | isla mujeres
# Processing Record 49 of Set 2 | santiago
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | prainha
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | karoi
# Processing Record 5 of Set 3 | cuamba
# Processing Record 6 of Set 3 | fort nelson
# Processing Record 7 of Set 3 | catole do rocha
# Processing Record 8 of Set 3 | wanlaweyn
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | belmonte
# Processing Record 13 of Set 3 | yar-sale
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | careiro da varzea
# Processing Record 17 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 3 | bila tserkva
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | shorapur
# Processing Record 21 of Set 3 | itoman
# Processing Record 22 of Set 3 | dingle
# Processing Record 23 of Set 3 | serenje
# Processing Record 24 of Set 3 | balabac
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | tabou
# Processing Record 27 of Set 3 | lompoc
# Processing Record 28 of Set 3 | vila do maio
# Processing Record 29 of Set 3 | buta
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | san antonio
# Processing Record 33 of Set 3 | bunia
# Processing Record 34 of Set 3 | huarmey
# Processing Record 35 of Set 3 | east wenatchee bench
# Processing Record 36 of Set 3 | potenza
# Processing Record 37 of Set 3 | jarjis
# City not found. Skipping...
# Processing Record 38 of Set 3 | terrace
# Processing Record 39 of Set 3 | ansalta
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | dunedin
# Processing Record 45 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 3 | shitanjing
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | la ronge
# Processing Record 1 of Set 4 | salinopolis
# Processing Record 2 of Set 4 | necochea
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | zlitan
# Processing Record 7 of Set 4 | avera
# Processing Record 8 of Set 4 | lithakia
# Processing Record 9 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 4 | margate
# Processing Record 11 of Set 4 | okhotsk
# Processing Record 12 of Set 4 | port blair
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | los llanos de aridane
# Processing Record 15 of Set 4 | ust-nera
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | magadan
# Processing Record 18 of Set 4 | straubing
# Processing Record 19 of Set 4 | cherskiy
# Processing Record 20 of Set 4 | meulaboh
# Processing Record 21 of Set 4 | waipawa
# Processing Record 22 of Set 4 | shawnee
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | bud
# Processing Record 26 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | kroonstad
# Processing Record 29 of Set 4 | escuinapa
# Processing Record 30 of Set 4 | tilichiki
# Processing Record 31 of Set 4 | wapakoneta
# Processing Record 32 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 4 | muros
# Processing Record 34 of Set 4 | ketchikan
# Processing Record 35 of Set 4 | luganville
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | doctor juan leon mallorquin
# Processing Record 38 of Set 4 | fallon
# Processing Record 39 of Set 4 | kuressaare
# Processing Record 40 of Set 4 | staryy nadym
# Processing Record 41 of Set 4 | mmabatho
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | kenitra
# Processing Record 44 of Set 4 | odweyne
# Processing Record 45 of Set 4 | eslov
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | birao
# Processing Record 48 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 4 | ozernovskiy
# Processing Record 50 of Set 4 | barras
# Processing Record 1 of Set 5 | linjiang
# Processing Record 2 of Set 5 | manakara
# Processing Record 3 of Set 5 | zhigansk
# Processing Record 4 of Set 5 | namatanai
# Processing Record 5 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 5 | otofuke
# Processing Record 7 of Set 5 | mayumba
# Processing Record 8 of Set 5 | phuntsholing
# Processing Record 9 of Set 5 | ust-tsilma
# Processing Record 10 of Set 5 | verkhoshizhemye
# Processing Record 11 of Set 5 | kamina
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | makow mazowiecki
# Processing Record 14 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 5 | matameye
# City not found. Skipping...
# Processing Record 16 of Set 5 | haimen
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | thinadhoo
# Processing Record 19 of Set 5 | chuy
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | popondetta
# Processing Record 22 of Set 5 | rayachoti
# Processing Record 23 of Set 5 | pokhara
# Processing Record 24 of Set 5 | tsiroanomandidy
# Processing Record 25 of Set 5 | gornopravdinsk
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | tasiilaq
# Processing Record 29 of Set 5 | kimbe
# Processing Record 30 of Set 5 | kayes
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | lubbock
# Processing Record 33 of Set 5 | vilcun
# Processing Record 34 of Set 5 | repnoye
# Processing Record 35 of Set 5 | zhob
# Processing Record 36 of Set 5 | dwarka
# Processing Record 37 of Set 5 | torbay
# Processing Record 38 of Set 5 | mporokoso
# Processing Record 39 of Set 5 | labuhan
# Processing Record 40 of Set 5 | acapulco
# Processing Record 41 of Set 5 | ponta do sol
# Processing Record 42 of Set 5 | fortuna
# Processing Record 43 of Set 5 | chincha alta
# Processing Record 44 of Set 5 | sabang
# Processing Record 45 of Set 5 | lima
# Processing Record 46 of Set 5 | tambaliza
# City not found. Skipping...
# Processing Record 47 of Set 5 | lagoa
# Processing Record 48 of Set 5 | karasjok
# Processing Record 49 of Set 5 | saskylakh
# Processing Record 50 of Set 5 | monroe
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | adwa
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | tsentoroy
# Processing Record 6 of Set 6 | tura
# Processing Record 7 of Set 6 | ancud
# Processing Record 8 of Set 6 | japura
# Processing Record 9 of Set 6 | gudari
# Processing Record 10 of Set 6 | miles city
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | kemi
# Processing Record 13 of Set 6 | belaya gora
# Processing Record 14 of Set 6 | tecoanapa
# Processing Record 15 of Set 6 | moerai
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | juneau
# Processing Record 18 of Set 6 | ca mau
# Processing Record 19 of Set 6 | padang
# Processing Record 20 of Set 6 | vila velha
# Processing Record 21 of Set 6 | punganuru
# Processing Record 22 of Set 6 | barnaul
# Processing Record 23 of Set 6 | santa cruz de la palma
# Processing Record 24 of Set 6 | longyearbyen
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | sitka
# Processing Record 27 of Set 6 | key west
# Processing Record 28 of Set 6 | nalut
# Processing Record 29 of Set 6 | llata
# Processing Record 30 of Set 6 | noumea
# Processing Record 31 of Set 6 | yaan
# Processing Record 32 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | la serena
# Processing Record 34 of Set 6 | bafq
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | saint-leu
# Processing Record 38 of Set 6 | miandrivazo
# Processing Record 39 of Set 6 | balkhash
# Processing Record 40 of Set 6 | teguldet
# Processing Record 41 of Set 6 | guilin
# Processing Record 42 of Set 6 | diffa
# Processing Record 43 of Set 6 | tsumeb
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | puerto ayacucho
# Processing Record 46 of Set 6 | sao paulo de olivenca
# Processing Record 47 of Set 6 | zwedru
# Processing Record 48 of Set 6 | stornoway
# Processing Record 49 of Set 6 | pochutla
# Processing Record 50 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 7 | walvis bay
# Processing Record 2 of Set 7 | ornskoldsvik
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | grantham
# Processing Record 5 of Set 7 | tuktoyaktuk
# Processing Record 6 of Set 7 | bela vista
# Processing Record 7 of Set 7 | pimenta bueno
# Processing Record 8 of Set 7 | tiruchchendur
# Processing Record 9 of Set 7 | shelburne
# Processing Record 10 of Set 7 | djambala
# Processing Record 11 of Set 7 | ballina
# Processing Record 12 of Set 7 | khasan
# Processing Record 13 of Set 7 | haicheng
# Processing Record 14 of Set 7 | taltal
# Processing Record 15 of Set 7 | tazovskiy
# Processing Record 16 of Set 7 | hithadhoo
# Processing Record 17 of Set 7 | sistranda
# Processing Record 18 of Set 7 | sao felix do xingu
# Processing Record 19 of Set 7 | kaitangata
# Processing Record 20 of Set 7 | samut songkhram
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | copiapo
# Processing Record 23 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 7 | arauco
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | broken hill
# Processing Record 27 of Set 7 | saint-augustin
# Processing Record 28 of Set 7 | afua
# Processing Record 29 of Set 7 | xudat
# Processing Record 30 of Set 7 | samarai
# Processing Record 31 of Set 7 | karratha
# Processing Record 32 of Set 7 | berlevag
# Processing Record 33 of Set 7 | taoudenni
# Processing Record 34 of Set 7 | kabare
# Processing Record 35 of Set 7 | ubinskoye
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | antalaha
# Processing Record 39 of Set 7 | sioux lookout
# Processing Record 40 of Set 7 | paamiut
# Processing Record 41 of Set 7 | hilton head island
# Processing Record 42 of Set 7 | ust-omchug
# Processing Record 43 of Set 7 | salta
# Processing Record 44 of Set 7 | merauke
# Processing Record 45 of Set 7 | sindgi
# Processing Record 46 of Set 7 | porto murtinho
# Processing Record 47 of Set 7 | kilindoni
# Processing Record 48 of Set 7 | quang ngai
# Processing Record 49 of Set 7 | madimba
# Processing Record 50 of Set 7 | nome
# Processing Record 1 of Set 8 | olafsvik
# Processing Record 2 of Set 8 | ginir
# Processing Record 3 of Set 8 | lakes entrance
# Processing Record 4 of Set 8 | petalcingo
# Processing Record 5 of Set 8 | kuala terengganu
# Processing Record 6 of Set 8 | hamilton
# Processing Record 7 of Set 8 | umm kaddadah
# Processing Record 8 of Set 8 | saint-joseph
# Processing Record 9 of Set 8 | aracati
# Processing Record 10 of Set 8 | buraydah
# Processing Record 11 of Set 8 | svetlogorsk
# Processing Record 12 of Set 8 | manali
# Processing Record 13 of Set 8 | seguela
# Processing Record 14 of Set 8 | sao desiderio
# Processing Record 15 of Set 8 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 16 of Set 8 | paso de carrasco
# Processing Record 17 of Set 8 | penne
# Processing Record 18 of Set 8 | sechura
# Processing Record 19 of Set 8 | ewa beach
# Processing Record 20 of Set 8 | port elizabeth
# Processing Record 21 of Set 8 | tuatapere
# Processing Record 22 of Set 8 | urucara
# Processing Record 23 of Set 8 | halifax
# Processing Record 24 of Set 8 | yerbogachen
# Processing Record 25 of Set 8 | port hardy
# Processing Record 26 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 8 | charters towers
# Processing Record 29 of Set 8 | bukachacha
# Processing Record 30 of Set 8 | macon
# Processing Record 31 of Set 8 | sovetskiy
# Processing Record 32 of Set 8 | iturama
# Processing Record 33 of Set 8 | clarence town
# Processing Record 34 of Set 8 | puerto colombia
# Processing Record 35 of Set 8 | katsuura
# Processing Record 36 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 37 of Set 8 | dehui
# Processing Record 38 of Set 8 | rafai
# Processing Record 39 of Set 8 | kapit
# Processing Record 40 of Set 8 | port hedland
# Processing Record 41 of Set 8 | oreanda
# City not found. Skipping...
# Processing Record 42 of Set 8 | somerset
# Processing Record 43 of Set 8 | natal
# Processing Record 44 of Set 8 | mercedes
# Processing Record 45 of Set 8 | santa maria
# Processing Record 46 of Set 8 | maturin
# Processing Record 47 of Set 8 | aquiraz
# Processing Record 48 of Set 8 | bria
# Processing Record 49 of Set 8 | bontang
# Processing Record 50 of Set 8 | gat
# Processing Record 1 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 9 | sorland
# Processing Record 3 of Set 9 | waddan
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | potiskum
# Processing Record 6 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 7 of Set 9 | zigong
# Processing Record 8 of Set 9 | illintsi
# Processing Record 9 of Set 9 | mookane
# Processing Record 10 of Set 9 | odessa
# Processing Record 11 of Set 9 | izumo
# Processing Record 12 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 13 of Set 9 | hami
# Processing Record 14 of Set 9 | kaniama
# Processing Record 15 of Set 9 | egvekinot
# Processing Record 16 of Set 9 | oktyabrskiy
# Processing Record 17 of Set 9 | solnechnyy
# Processing Record 18 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 9 | poum
# Processing Record 20 of Set 9 | north bend
# Processing Record 21 of Set 9 | puerto el triunfo
# Processing Record 22 of Set 9 | cockburn town
# Processing Record 23 of Set 9 | eyl
# Processing Record 24 of Set 9 | macklin
# Processing Record 25 of Set 9 | wuwei
# Processing Record 26 of Set 9 | elesbao veloso
# Processing Record 27 of Set 9 | codrington
# Processing Record 28 of Set 9 | karakol
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | araouane
# Processing Record 31 of Set 9 | zabol
# Processing Record 32 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 9 | sheffield lake
# Processing Record 34 of Set 9 | baiyin
# Processing Record 35 of Set 9 | lalibela
# Processing Record 36 of Set 9 | beinamar
# Processing Record 37 of Set 9 | shelabolikha
# Processing Record 38 of Set 9 | nadezhda
# Processing Record 39 of Set 9 | gotsu
# Processing Record 40 of Set 9 | kupang
# Processing Record 41 of Set 9 | haines junction
# Processing Record 42 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 9 | christchurch
# Processing Record 44 of Set 9 | rascani
# City not found. Skipping...
# Processing Record 45 of Set 9 | shache
# Processing Record 46 of Set 9 | olinda
# Processing Record 47 of Set 9 | babanka
# Processing Record 48 of Set 9 | arandis
# Processing Record 49 of Set 9 | papayal
# Processing Record 50 of Set 9 | kampene
# Processing Record 1 of Set 10 | homer
# Processing Record 2 of Set 10 | rabo de peixe
# Processing Record 3 of Set 10 | qabaqcol
# Processing Record 4 of Set 10 | aksarka
# Processing Record 5 of Set 10 | cocentaina
# Processing Record 6 of Set 10 | pishva
# Processing Record 7 of Set 10 | pskov
# Processing Record 8 of Set 10 | saint-doulchard
# Processing Record 9 of Set 10 | pelym
# Processing Record 10 of Set 10 | husavik
# Processing Record 11 of Set 10 | saint-georges
# Processing Record 12 of Set 10 | methoni
# Processing Record 13 of Set 10 | manyana
# Processing Record 14 of Set 10 | grindavik
# Processing Record 15 of Set 10 | camana
# Processing Record 16 of Set 10 | udachnyy
# Processing Record 17 of Set 10 | lumeje
# Processing Record 18 of Set 10 | dunda
# Processing Record 19 of Set 10 | omagari
# Processing Record 20 of Set 10 | jadu
# Processing Record 21 of Set 10 | san rafael
# Processing Record 22 of Set 10 | hailar
# Processing Record 23 of Set 10 | florence
# Processing Record 24 of Set 10 | eureka
# Processing Record 25 of Set 10 | amga
# Processing Record 26 of Set 10 | le mans
# Processing Record 27 of Set 10 | mina
# Processing Record 28 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 10 | wangaratta
# Processing Record 30 of Set 10 | el alto
# Processing Record 31 of Set 10 | brasilia de minas
# Processing Record 32 of Set 10 | clayton
# Processing Record 33 of Set 10 | turukhansk
# Processing Record 34 of Set 10 | vao
# Processing Record 35 of Set 10 | nova olimpia
# Processing Record 36 of Set 10 | beringovskiy
# Processing Record 37 of Set 10 | westport
# Processing Record 38 of Set 10 | usinsk
# Processing Record 39 of Set 10 | abong mbang
# Processing Record 40 of Set 10 | sumter
# Processing Record 41 of Set 10 | rio gallegos
# Processing Record 42 of Set 10 | batagay-alyta
# Processing Record 43 of Set 10 | vidim
# Processing Record 44 of Set 10 | ambanja
# Processing Record 45 of Set 10 | pareora
# Processing Record 46 of Set 10 | ilo
# Processing Record 47 of Set 10 | khorramshahr
# Processing Record 48 of Set 10 | dukhovnitskoye
# Processing Record 49 of Set 10 | fuyu
# Processing Record 50 of Set 10 | ixtapa
# Processing Record 1 of Set 11 | palmer
# Processing Record 2 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 11 | takoradi
# Processing Record 4 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 11 | oranjemund
# Processing Record 6 of Set 11 | rosetta
# Processing Record 7 of Set 11 | san quintin
# Processing Record 8 of Set 11 | vuktyl
# Processing Record 9 of Set 11 | bojnurd
# Processing Record 10 of Set 11 | fairlie
# Processing Record 11 of Set 11 | kologriv
# Processing Record 12 of Set 11 | faranah
# Processing Record 13 of Set 11 | ambatofinandrahana
# Processing Record 14 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 15 of Set 11 | xiamen
# Processing Record 16 of Set 11 | jamiltepec
# Processing Record 17 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | coihaique
# Processing Record 19 of Set 11 | agapia
# Processing Record 20 of Set 11 | mareeba
# Processing Record 21 of Set 11 | choya
# Processing Record 22 of Set 11 | harper
# Processing Record 23 of Set 11 | okha
# Processing Record 24 of Set 11 | basco
# Processing Record 25 of Set 11 | flin flon
# Processing Record 26 of Set 11 | derzhavinsk
# Processing Record 27 of Set 11 | nelson bay
# Processing Record 28 of Set 11 | ambagarh chauki
# Processing Record 29 of Set 11 | pangai
# Processing Record 30 of Set 11 | tacuati
# Processing Record 31 of Set 11 | manavalakurichi
# Processing Record 32 of Set 11 | te anau
# Processing Record 33 of Set 11 | puerto escondido
# Processing Record 34 of Set 11 | sur
# Processing Record 35 of Set 11 | tupik
# Processing Record 36 of Set 11 | mashhad
# Processing Record 37 of Set 11 | bagru
# Processing Record 38 of Set 11 | bhind
# Processing Record 39 of Set 11 | uusikaupunki
# Processing Record 40 of Set 11 | bam
# Processing Record 41 of Set 11 | weihai
# Processing Record 42 of Set 11 | sooke
# Processing Record 43 of Set 11 | clyde river
# Processing Record 44 of Set 11 | bodden town
# Processing Record 45 of Set 11 | visnes
# Processing Record 46 of Set 11 | valmiera
# Processing Record 47 of Set 11 | hobyo
# Processing Record 48 of Set 11 | le moule
# Processing Record 49 of Set 11 | kiruna
# Processing Record 50 of Set 11 | kaduna
# Processing Record 1 of Set 12 | havoysund
# Processing Record 2 of Set 12 | rincon
# Processing Record 3 of Set 12 | qaqortoq
# Processing Record 4 of Set 12 | gunjur
# Processing Record 5 of Set 12 | salinas
# Processing Record 6 of Set 12 | lorengau
# Processing Record 7 of Set 12 | butembo
# Processing Record 8 of Set 12 | teahupoo
# Processing Record 9 of Set 12 | coahuayana
# Processing Record 10 of Set 12 | zaozerne
# Processing Record 11 of Set 12 | komatipoort
# Processing Record 12 of Set 12 | acarau
# Processing Record 13 of Set 12 | liberal
# Processing Record 14 of Set 12 | nipawin
# Processing Record 15 of Set 12 | batemans bay
# Processing Record 16 of Set 12 | pombia
# Processing Record 17 of Set 12 | matara
# Processing Record 18 of Set 12 | ust-maya
# Processing Record 19 of Set 12 | manzhouli
# Processing Record 20 of Set 12 | ariyalur
# Processing Record 21 of Set 12 | porbandar
# Processing Record 22 of Set 12 | omboue
# Processing Record 23 of Set 12 | caraquet
# Processing Record 24 of Set 12 | valparaiso
# Processing Record 25 of Set 12 | ongandjera
# Processing Record 26 of Set 12 | belovo
# Processing Record 27 of Set 12 | iqaluit
# Processing Record 28 of Set 12 | srednekolymsk
# Processing Record 29 of Set 12 | kiunga
# Processing Record 30 of Set 12 | bonnyville
# Processing Record 31 of Set 12 | ulkan
# Processing Record 32 of Set 12 | zakamensk
# Processing Record 33 of Set 12 | koumac
# Processing Record 34 of Set 12 | henties bay
# Processing Record 35 of Set 12 | jinchang
# Processing Record 36 of Set 12 | poronaysk
# Processing Record 37 of Set 12 | bereda
# Processing Record 38 of Set 12 | saint anthony
# Processing Record 39 of Set 12 | ponta delgada
# Processing Record 40 of Set 12 | whitehorse
# Processing Record 41 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 12 | kavieng
# Processing Record 43 of Set 12 | arlit
# Processing Record 44 of Set 12 | kodinsk
# Processing Record 45 of Set 12 | rexburg
# Processing Record 46 of Set 12 | comodoro rivadavia
# Processing Record 47 of Set 12 | vaitape
# Processing Record 48 of Set 12 | broome
# Processing Record 49 of Set 12 | sarnia
# Processing Record 50 of Set 12 | kununurra
# Processing Record 1 of Set 13 | deshna
# City not found. Skipping...
# Processing Record 2 of Set 13 | richards bay
# Processing Record 3 of Set 13 | pacific grove
# Processing Record 4 of Set 13 | constantine
# Processing Record 5 of Set 13 | kruisfontein
# Processing Record 6 of Set 13 | bundi
# Processing Record 7 of Set 13 | barranca
# Processing Record 8 of Set 13 | rio grande
# Processing Record 9 of Set 13 | beloha
# Processing Record 10 of Set 13 | maragogi
# Processing Record 11 of Set 13 | newport
# Processing Record 12 of Set 13 | flinders
# Processing Record 13 of Set 13 | cody
# Processing Record 14 of Set 13 | sol-iletsk
# Processing Record 15 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 13 | sidrolandia
# Processing Record 17 of Set 13 | berezovyy
# Processing Record 18 of Set 13 | roma
# Processing Record 19 of Set 13 | yinchuan
# Processing Record 20 of Set 13 | lampa
# Processing Record 21 of Set 13 | hargeysa
# Processing Record 22 of Set 13 | quelimane
# Processing Record 23 of Set 13 | ketchenery
# City not found. Skipping...
# Processing Record 24 of Set 13 | jacmel
# Processing Record 25 of Set 13 | igra
# Processing Record 26 of Set 13 | sokoni
# Processing Record 27 of Set 13 | neiafu
# Processing Record 28 of Set 13 | kawalu
# Processing Record 29 of Set 13 | jasper
# Processing Record 30 of Set 13 | ambilobe
# Processing Record 31 of Set 13 | nyandoma
# Processing Record 32 of Set 13 | beruwala
# Processing Record 33 of Set 13 | iquitos
# Processing Record 34 of Set 13 | turayf
# Processing Record 35 of Set 13 | verkhnetulomskiy
# Processing Record 36 of Set 13 | bartica
# Processing Record 37 of Set 13 | ginda
# Processing Record 38 of Set 13 | rubtsovsk
# Processing Record 39 of Set 13 | indiana
# Processing Record 40 of Set 13 | tuburan
# Processing Record 41 of Set 13 | kirksville
# Processing Record 42 of Set 13 | estacion coahuila
# Processing Record 43 of Set 13 | caravelas
# Processing Record 44 of Set 13 | saint-pierre
# Processing Record 45 of Set 13 | gigmoto
# Processing Record 46 of Set 13 | beni
# Processing Record 47 of Set 13 | marawi
# Processing Record 48 of Set 13 | asfi
# Processing Record 49 of Set 13 | bhadrak
# Processing Record 50 of Set 13 | jinka
# Processing Record 1 of Set 14 | namibe
# Processing Record 2 of Set 14 | igrim
# Processing Record 3 of Set 14 | inirida
# Processing Record 4 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 14 | gillette
# Processing Record 6 of Set 14 | tessalit
# Processing Record 7 of Set 14 | santa rosa
# Processing Record 8 of Set 14 | lucea
# Processing Record 9 of Set 14 | govindgarh
# Processing Record 10 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 14 | carlsbad
# Processing Record 12 of Set 14 | marang
# Processing Record 13 of Set 14 | raudeberg
# Processing Record 14 of Set 14 | tabursuq
# Processing Record 15 of Set 14 | hambantota
# Processing Record 16 of Set 14 | zabid
# Processing Record 17 of Set 14 | kichera
# Processing Record 18 of Set 14 | jieshi
# Processing Record 19 of Set 14 | brae
# Processing Record 20 of Set 14 | erzin
# Processing Record 21 of Set 14 | byron bay
# Processing Record 22 of Set 14 | puqi
# Processing Record 23 of Set 14 | nabire
# Processing Record 24 of Set 14 | amot
# Processing Record 25 of Set 14 | wonogiri
# Processing Record 26 of Set 14 | pringsewu
# Processing Record 27 of Set 14 | sinnamary
# Processing Record 28 of Set 14 | geraldton
# Processing Record 29 of Set 14 | obo
# Processing Record 30 of Set 14 | madarounfa
# Processing Record 31 of Set 14 | dodola
# Processing Record 32 of Set 14 | novoagansk
# Processing Record 33 of Set 14 | veinticinco de mayo
# Processing Record 34 of Set 14 | semey
# Processing Record 35 of Set 14 | say
# Processing Record 36 of Set 14 | pauini
# Processing Record 37 of Set 14 | stefan cel mare
# Processing Record 38 of Set 14 | balakhonovskoye
# Processing Record 39 of Set 14 | cherdakly
# Processing Record 40 of Set 14 | svetlyy
# Processing Record 41 of Set 14 | maceio
# Processing Record 42 of Set 14 | atbasar
# Processing Record 43 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 14 | linxia
# Processing Record 46 of Set 14 | vestmannaeyjar
# Processing Record 47 of Set 14 | coquimbo
# Processing Record 48 of Set 14 | talas
# Processing Record 49 of Set 14 | zolochiv
# Processing Record 50 of Set 14 | vostok
# Processing Record 1 of Set 15 | isparta
# Processing Record 2 of Set 15 | dosso
# Processing Record 3 of Set 15 | aldergrove
# Processing Record 4 of Set 15 | porto walter
# Processing Record 5 of Set 15 | betioky
# Processing Record 6 of Set 15 | yurginskoye
# Processing Record 7 of Set 15 | meadow lake
# Processing Record 8 of Set 15 | dumai
# Processing Record 9 of Set 15 | saveh
# Processing Record 10 of Set 15 | valdivia
# Processing Record 11 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 15 | kotelnikovo
# Processing Record 13 of Set 15 | frontera
# Processing Record 14 of Set 15 | tual
# Processing Record 15 of Set 15 | ayan
# Processing Record 16 of Set 15 | paso de los toros
# Processing Record 17 of Set 15 | ossora
# Processing Record 18 of Set 15 | villa bruzual
# Processing Record 19 of Set 15 | xuanhua
# Processing Record 20 of Set 15 | ayacucho
# Processing Record 21 of Set 15 | batagay
# Processing Record 22 of Set 15 | amapa
# Processing Record 23 of Set 15 | northam
# Processing Record 24 of Set 15 | bayburt
# Processing Record 25 of Set 15 | port moresby
# Processing Record 26 of Set 15 | celestun
# Processing Record 27 of Set 15 | dinguiraye
# Processing Record 28 of Set 15 | faya
# Processing Record 29 of Set 15 | san pedro de ycuamandiyu
# Processing Record 30 of Set 15 | sokur
# Processing Record 31 of Set 15 | nicoya
# Processing Record 32 of Set 15 | galesong
# Processing Record 33 of Set 15 | carutapera
# Processing Record 34 of Set 15 | hunterville
# Processing Record 35 of Set 15 | lawrenceburg
# Processing Record 36 of Set 15 | mikkeli
# Processing Record 37 of Set 15 | alashtar
# City not found. Skipping...
# Processing Record 38 of Set 15 | seydi
# Processing Record 39 of Set 15 | kahului
# Processing Record 40 of Set 15 | nishihara
# Processing Record 41 of Set 15 | bundaberg
# Processing Record 42 of Set 15 | troitskoye
# Processing Record 43 of Set 15 | mount pleasant
# Processing Record 44 of Set 15 | tautira
# Processing Record 45 of Set 15 | marzuq
# Processing Record 46 of Set 15 | mandera
# Processing Record 47 of Set 15 | bogorodskoye
# Processing Record 48 of Set 15 | kungurtug
# Processing Record 49 of Set 15 | auki
# Processing Record 50 of Set 15 | manacapuru
# Processing Record 1 of Set 16 | duncan
# Processing Record 2 of Set 16 | lumberton
# Processing Record 3 of Set 16 | statesboro
# Processing Record 4 of Set 16 | oksfjord
# Processing Record 5 of Set 16 | nuevo casas grandes
# Processing Record 6 of Set 16 | arman
# Processing Record 7 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 16 | boissevain
# Processing Record 9 of Set 16 | pemangkat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Airai      TL  -8.9266  125.4092     63.97        91          94
# 1  Birnin Kebbi      NG  12.4539    4.1975    100.09        16           7
# 2       Ushuaia      AR -54.8000  -68.3000     49.66        57          40
# 3  Puerto Ayora      EC  -0.7393  -90.3518     73.36        78          97
# 4          Lepe      ES  37.2548   -7.2043     78.12        50          54
# 5          Hilo      US  19.7297 -155.0900     71.33        95          90
# 6   Yellowknife      CA  62.4560 -114.3525     34.41       100          75
# 7     Cape Town      ZA -33.9258   18.4232     65.26        57          20
# 8     Busselton      AU -33.6500  115.3333     67.05        64          57
# 9         Kapaa      US  22.0752 -159.3190     73.72        81          75
#
#    Wind Speed   Current Description
# 0        1.14       overcast clouds
# 1        6.26             clear sky
# 2        4.61      scattered clouds
# 3       11.05       overcast clouds
# 4       12.10         broken clouds
# 5        8.05  heavy intensity rain
# 6        8.05         broken clouds
# 7        8.01            light rain
# 8       10.85         broken clouds
# 9        1.01            light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
